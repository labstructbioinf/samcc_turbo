# %%
import samcc_turbo

# %%
# list all options
help(samcc_turbo.run_samcc_turbo)
# Out:
# Help on function run_samcc_turbo in module samcc_turbo.mierzaczka_turbo:
#
# run_samcc_turbo(pdbpath, mode='auto-detect', deffile=None, defdata=None, plot=True, save_df=True, save_pse=True, bin_paths={'socket': 'socket', 'dssp': 'dssp'}, layer_detect_n=5, max_dist='auto', search_set_n=3)
#     Main function for running samcc-turbo.
#
#     Arguments (general):
#     pdbpath   -- path to pdb file (.pdb)
#     mode      -- mode of running SamCC (default 'auto-detect')
#                - auto-detect: automatic detection of layers in the bundle (requires
#                               installed dssp and Socket)
#                        - defdata: use layer definition from list
#                - deffile: use layer definition from file
#     deffile   -- path to file defining layers used in deffile mode (default None)
#     plot      -- plot results and also save plot to file (default True)
#     save_df   -- save result DataFrame to pickle (default True)
# ...

# %%
# running with provided bundle definition as a list of parameters
defdata = [[range(8, 47), range(8, 47), range(8,47)[::-1], range(8,47)[::-1]],
           ['A', 'B', 'C', 'D'],
           [False, False, True, True],
           ['d', 'd', 'g', 'g']]

samcc_turbo.run_samcc_turbo('./examples/1qx8.pdb1', mode='defdata', defdata=defdata)
# Out:
# Saving pymol session with layers...
# 1qx8 saved.

# %%
# running in most default mode (auto-detect, just point dssp and socket binaries)

bin_paths = {'dssp':'dssp', 'socket':'/home/kszczepaniak/Apps/socket3.03/socket'}
samcc_turbo.run_samcc_turbo('./examples/1qx8.pdb1', bin_paths=bin_paths)
# Out:
# 1qx8.dssp
# Saving pymol session with layers...
# 1qx8 saved.

# %%
# run in deffile mode - future
# samcc_turbo.run_samcc_turbo('./examples/1qx8.pdb1', mode='deffile', deffile='./examples/1qx8.scd')
